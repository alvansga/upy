# %% [markdown]
# ## convert gif or video into png per frame

# %%
mkdir frames
ffmpeg -i video.mp4 -vf "fps=10,scale=128:64" frames/frame_%03d.png

# %%
mkdir out
python 02_convert_to_ssd1306.py

# %% [markdown]
# ## gabung jadi satu .bin pakai cat (wsl)

# %%
cat out/*.bin > anim.bin

# %% [markdown]
# ## Upload anim.bin dgn thonny

# %% [markdown]
# ## Upload main_anim.py
